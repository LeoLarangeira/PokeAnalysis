# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoLarangeira/PokeAnalysis/blob/main/pandas_aula05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Pokemon.csv')

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['#'].plot(kind='hist', bins=20, title='#')
# ...

# %%
df.columns = ['#','Nome','Tipo 1','Tipo 2', 'Total', 'HP', 'Ataque', 'Defesa', 'Sp.Ata', 'Sp.Def','Velocidade', 'Geracao', 'Lendario']
df.head(2)
# Out:
#    #       Nome Tipo 1  Tipo 2  Total  HP  Ataque  Defesa  Sp.Ata  Sp.Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49      49      65      65
# 1  2    Ivysaur  Grass  Poison    405  60      62      63      80      80
#
#    Velocidade  Geracao  Lendario
# 0          45        1     False
# 1          60        1     False

# %%
def max_stats(df, col_list):

    saida =''
    for col in col_list:
        stat = df[col].max()
        name = df[df[col]==df[col].max()]['Nome'].values[0]
        saida += name + ' possui o/a maior '+col+ ' com '+ str(stat) + '  |   '
    return saida


stats = ['Ataque', 'Defesa', 'Sp.Ata']
max_stats(df,stats)
# Out:
# 'MewtwoMega Mewtwo X possui o/a maior Ataque com 190  |   SteelixMega Steelix possui o/a maior Defesa com 230  |   MewtwoMega Mewtwo Y possui o/a maior Sp.Ata com 194  |   '

# %%
types = df["Tipo 1"].unique()

def barh_stats():
    plt.figure(figsize=(15,5))
    plt.suptitle('Statistics', fontsize=15)

    for t in types:

        #Plotting Mean
        plt.subplot(121)
        plt.title('Mean')
        df[df['Tipo 1']==t].mean().plot(kind='barh')

        #Plotting Standard Deviation
        plt.subplot(122)
        plt.title('Standard Deviation')
        df[df['Tipo 1']==t].std().plot(kind='barh')


barh_stats()
# Out:
# <ipython-input-12-4cf786ab4121>:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['Tipo 1']==t].mean().plot(kind='barh')
# <ipython-input-12-4cf786ab4121>:17: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['Tipo 1']==t].std().plot(kind='barh')
# ...

# %%
def max_stats(df, col_list):
    fig, ax = plt.subplots(figsize=(8, 6))

    for col in col_list:
        stat = df[col].max()
        name = df[df[col] == stat]['Nome'].values[0]
        ax.bar(col, stat, label=name)

    ax.set_ylabel('Valor máximo')
    ax.set_title('Maiores estatísticas')
    ax.legend()

    # Salvar o gráfico em um buffer de memória
    buffer = io.BytesIO()
    plt.savefig(buffer, format='png')
    buffer.seek(0)

    # Converter o buffer para uma string base64
    buffer_str = base64.b64encode(buffer.read()).decode()

    # Criar a tag HTML para a imagem
    img_tag = f'<img src="data:image/png;base64,{buffer_str}">'

    # Fechar a figura para liberar memória
    plt.close(fig)

    return img_tag

stats = ['Ataque', 'Defesa', 'Sp.Ata']
graph_html = max_stats(df, stats)
print(graph_html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ec9c2381dbf1> in <cell line: 30>()
#      28
#      29 stats = ['Ataque', 'Defesa', 'Sp.Ata']
# ---> 30 graph_html = max_stats(df, stats)
#      31 print(graph_html)
#
# <ipython-input-17-ec9c2381dbf1> in max_stats(df, col_list)
#      12
#      13     # Salvar o gráfico em um buffer de memória
# ---> 14     buffer = io.BytesIO()
#      15     plt.savefig(buffer, format='png')
#      16     buffer.seek(0)
#
# NameError: name 'io' is not defined
